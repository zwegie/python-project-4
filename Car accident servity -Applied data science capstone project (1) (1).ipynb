# %%
#Car accident servity project
#importing ibraries
import pandas as  pd
import numpy as np

# %%
pwd
# Out:
# 'C:\\Users\\ravij25'

# %%
df=pd.read_csv(r"C:\Users\ravij25\Desktop\car_uk-19.csv")

# %%
df.head()
# Out:
#    Grid Ref: Easting  Grid Ref: Northing  Number of Vehicles Accident Date  \
# 0             423194              438111                   1    01/01/2019
# 1             431451              435823                   1    02/01/2019
# 2             427555              433891                   2    03/01/2019
# 3             427140              437363                   3    03/01/2019
# 4             430783              438603                   2    04/01/2019
#
#    Time (24hr)  1st Road Class 1st Road Class & No  Road Surface  \
# 0         1505               6                   U             1
# 1         1915               6                   U             1
# 2          955               6                   U             1
# 3         1128               3                A660             1
# 4          746               6                   U             1
#
#    Lighting Conditions  Weather Conditions Local Authority  Vehicle Number  \
# ...

# %%
df.tail()
# Out:
#       Grid Ref: Easting  Grid Ref: Northing  Number of Vehicles Accident Date  \
# 1290             430100              431497                   2    29/12/2019
# 1291             430040              434040                   1    29/12/2019
# 1292             442094              434619                   1    30/12/2019
# 1293             421466              433999                   3    31/12/2019
# 1294             421466              433999                   3    31/12/2019
#
#       Time (24hr)  1st Road Class 1st Road Class & No  Road Surface  \
# 1290          152               6                   U             1
# 1291          220               6                   U             1
# 1292          422               1                  M1             2
# 1293         1640               3                A647             1
# 1294         1640               3                A647             1
#
#       Lighting Conditions  Weather Conditions Local Authority  Vehicle Number  \
# ...

# %%
df.shape
# Out:
# (1295, 17)

# %%
df.dtypes
# Out:
# Grid Ref: Easting       int64
# Grid Ref: Northing      int64
# Number of Vehicles      int64
# Accident Date          object
# Time (24hr)             int64
# 1st Road Class          int64
# 1st Road Class & No    object
# Road Surface            int64
# Lighting Conditions     int64
# Weather Conditions      int64
# Local Authority        object
# Vehicle Number          int64
# Type of Vehicle         int64
# Casualty Class          int64
# Casualty Severity       int64
# Sex of Casualty         int64
# Age of Casualty         int64
# dtype: object

# %%
df.corr()
# Out:
#                      Grid Ref: Easting  Grid Ref: Northing  \
# Grid Ref: Easting             1.000000            0.037735
# Grid Ref: Northing            0.037735            1.000000
# Number of Vehicles            0.135897           -0.128174
# Time (24hr)                  -0.045143           -0.065618
# 1st Road Class               -0.169505            0.190365
# Road Surface                 -0.071187            0.026076
# Lighting Conditions          -0.083847           -0.054861
# Weather Conditions           -0.043885            0.073848
# Vehicle Number                0.102661           -0.111535
# Type of Vehicle                    NaN                 NaN
# Casualty Class               -0.048065            0.058070
# Casualty Severity             0.002992           -0.009046
# Sex of Casualty               0.029438            0.026572
# Age of Casualty               0.029083            0.064294
#
#                      Number of Vehicles  Time (24hr)  1st Road Class  \
# ...

# %%
df.columns
# Out:
# Index(['Grid Ref: Easting', 'Grid Ref: Northing', 'Number of Vehicles',
#        'Accident Date', 'Time (24hr)', '1st Road Class', '1st Road Class & No',
#        'Road Surface', 'Lighting Conditions', 'Weather Conditions',
#        'Local Authority', 'Vehicle Number', 'Type of Vehicle',
#        'Casualty Class', 'Casualty Severity', 'Sex of Casualty',
#        'Age of Casualty'],
#       dtype='object')

# %%
df2=df[['1st Road Class', '1st Road Class & No',
       'Road Surface', 'Lighting Conditions', 'Weather Conditions',
       'Casualty Class',  'Sex of Casualty',
       'Age of Casualty']]

# %%
#DATA PREPARATION

# %%
df.isnull().sum()
# Out:
# Grid Ref: Easting      0
# Grid Ref: Northing     0
# Number of Vehicles     0
# Accident Date          0
# Time (24hr)            0
# 1st Road Class         0
# 1st Road Class & No    0
# Road Surface           0
# Lighting Conditions    0
# Weather Conditions     0
# Local Authority        0
# Vehicle Number         0
# Type of Vehicle        0
# Casualty Class         0
# Casualty Severity      0
# Sex of Casualty        0
# Age of Casualty        0
# dtype: int64

# %%
df['Casualty Severity'].value_counts()
# Out:
# 3    1110
# 2     173
# 1      12
# Name: Casualty Severity, dtype: int64

# %%
import matplotlib.pyplot as plt

# %%
df.hist(figsize=(30,20))
plt.show()

# %%
import seaborn as sns

# %%
sns.set(style="white")
sns.set(style="whitegrid", color_codes=True)
sns.heatmap(df2.corr())
plt.show()

# %%
df.hist(column="Casualty Severity")
plt.show()

# %%
import itertools
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.ticker import NullFormatter
import pandas as pd
import numpy as np
import matplotlib.ticker as ticker
from sklearn import preprocessing
# %matplotlib inline

# %%
df.columns
# Out:
# Index(['Grid Ref: Easting', 'Grid Ref: Northing', 'Number of Vehicles',
#        'Accident Date', 'Time (24hr)', '1st Road Class', '1st Road Class & No',
#        'Road Surface', 'Lighting Conditions', 'Weather Conditions',
#        'Local Authority', 'Vehicle Number', 'Type of Vehicle',
#        'Casualty Class', 'Casualty Severity', 'Sex of Casualty',
#        'Age of Casualty'],
#       dtype='object')

# %%
import matplotlib.ticker as mtick
import matplotlib.pyplot as plt

df.groupby(['Casualty Severity','Weather Conditions']).size().groupby(level=0).apply(
    lambda x: 100 * x / x.sum()
).unstack().plot(kind='bar',stacked=True)

plt.gca().yaxis.set_major_formatter(mtick.PercentFormatter())
plt.show()

# %%
import matplotlib.ticker as mtick
import matplotlib.pyplot as plt

df.groupby(['Casualty Severity','Lighting Conditions']).size().groupby(level=0).apply(
    lambda x: 100 * x / x.sum()
).unstack().plot(kind='bar',stacked=True)

plt.gca().yaxis.set_major_formatter(mtick.PercentFormatter())
plt.show()

# %%
import matplotlib.ticker as mtick
import matplotlib.pyplot as plt

df.groupby(['Casualty Severity','Road Surface']).size().groupby(level=0).apply(
    lambda x: 100 * x / x.sum()
).unstack().plot(kind='bar',stacked=True)

plt.gca().yaxis.set_major_formatter(mtick.PercentFormatter())
plt.show()

# %%
import matplotlib.ticker as mtick
import matplotlib.pyplot as plt

df.groupby(['Casualty Severity','1st Road Class']).size().groupby(level=0).apply(
    lambda x: 100 * x / x.sum()
).unstack().plot(kind='bar',stacked=True)

plt.gca().yaxis.set_major_formatter(mtick.PercentFormatter())

# %%
import matplotlib.ticker as mtick
import matplotlib.pyplot as plt

df.groupby(['Casualty Severity','Sex of Casualty']).size().groupby(level=0).apply(
    lambda x: 100 * x / x.sum()
).unstack().plot(kind='bar',stacked=True)

plt.gca().yaxis.set_major_formatter(mtick.PercentFormatter())
plt.show()

# %%
for s in np.arange(1,5):
    plt.subplots(figsize=(12,5))
    df.loc[df["Casualty Severity"] == s],df['Road Surface'].value_counts().sort_values(ascending=False).head(20).plot.bar(width=0.5,color='green', edgecolor='k',align='center',linewidth=1)
    plt.xlabel('Road Surface',fontsize=16)
    plt.ylabel(' car accident servity count',fontsize=16)
    plt.title('20 of The Main Road Surface Conditions for Accidents of Severity ' + str(s),fontsize=16)
    plt.xticks(fontsize=16)
    plt.yticks(fontsize=16)

# %%
for s in np.arange(1,5):
    plt.subplots(figsize=(12,5))
    df.loc[df["Casualty Severity"] == s],df['Lighting Conditions'].value_counts().sort_values(ascending=False).head(20).plot.bar(width=0.5,color='pink', edgecolor='k',align='center',linewidth=1)
    plt.xlabel('Lighting Conditions',fontsize=16)
    plt.ylabel(' Car accident servity count',fontsize=16)
    plt.title('20 of The Main Lighting Conditions for car Accidents of Severity ' + str(s),fontsize=16)
    plt.xticks(fontsize=16)
    plt.yticks(fontsize=16)

# %%
for s in np.arange(1,5):
    plt.subplots(figsize=(12,5))
    df.loc[df["Casualty Severity"] == s],df['Sex of Casualty'].value_counts().sort_values(ascending=False).head(20).plot.bar(width=0.5,color='blue', edgecolor='k',align='center',linewidth=1)
    plt.xlabel('Sex of Casualty',fontsize=16)
    plt.ylabel(' Car accident servity count',fontsize=16)
    plt.title('20 of The Main Sex of Casualty for car Accidents of Severity ' + str(s),fontsize=16)
    plt.xticks(fontsize=16)
    plt.yticks(fontsize=16)

# %%
for s in np.arange(1,5):
    plt.subplots(figsize=(12,5))
    df.loc[df["Casualty Severity"] == s],df['Age of Casualty'].value_counts().sort_values(ascending=False).head(20).plot.bar(width=0.5,color='brown', edgecolor='k',align='center',linewidth=1)
    plt.xlabel('Age of Casualty',fontsize=16)
    plt.ylabel(' Car accident servity count',fontsize=16)
    plt.title('20 of The Main Age of Casualty for car Accidents of Severity ' + str(s),fontsize=16)
    plt.xticks(fontsize=16)
    plt.yticks(fontsize=16)

# %%
for s in np.arange(1,5):
    plt.subplots(figsize=(12,5))
    df.loc[df["Casualty Severity"] == s],df['1st Road Class & No'].value_counts().sort_values(ascending=False).head(20).plot.bar(width=0.5,color='yellow', edgecolor='k',align='center',linewidth=1)
    plt.xlabel('1st Road Class & No',fontsize=16)
    plt.ylabel(' car accident servity count',fontsize=16)
    plt.title('20 of The Main 1st Road Class & No s for car Accidents of Severity ' + str(s),fontsize=16)
    plt.xticks(fontsize=16)
    plt.yticks(fontsize=16)

# %%
for s in np.arange(1,5):
    plt.subplots(figsize=(12,5))
    df.loc[df["Casualty Severity"] == s],df['Time (24hr)'].value_counts().sort_values(ascending=False).head(20).plot.bar(width=0.5,color='yellow', edgecolor='k',align='center',linewidth=1)
    plt.xlabel('Time (24hr)',fontsize=16)
    plt.ylabel(' Car accident servity count',fontsize=16)
    plt.title('20 of The Main Time (24hr)  for car Accidents of Severity ' + str(s),fontsize=16)
    plt.xticks(fontsize=16)
    plt.yticks(fontsize=16)

# %%
for s in np.arange(1,5):
    plt.subplots(figsize=(12,5))
    df.loc[df["Casualty Severity"] == s],df['Casualty Class'].value_counts().sort_values(ascending=False).head(20).plot.bar(width=0.5,color='red', edgecolor='k',align='center',linewidth=1)
    plt.xlabel('Casualty Class',fontsize=16)
    plt.ylabel(' Car accident servity count',fontsize=16)
    plt.title('20 of The Main Casualty Class for car Accidents of Severity ' + str(s),fontsize=16)
    plt.xticks(fontsize=16)
    plt.yticks(fontsize=16)

# %%
for s in np.arange(1,5):
    plt.subplots(figsize=(12,5))
    df.loc[df["Casualty Severity"] == s],df['1st Road Class'].value_counts().sort_values(ascending=False).head(20).plot.bar(width=0.5,color='pink', edgecolor='k',align='center',linewidth=1)
    plt.xlabel('1st Road Class',fontsize=16)
    plt.ylabel(' Car accident servity count',fontsize=16)
    plt.title('20 of The Main Weather Conditions for car Accidents of Severity ' + str(s),fontsize=16)
    plt.xticks(fontsize=16)
    plt.yticks(fontsize=16)

# %%
df.columns
# Out:
# Index(['Grid Ref: Easting', 'Grid Ref: Northing', 'Number of Vehicles',
#        'Accident Date', 'Time (24hr)', '1st Road Class', '1st Road Class & No',
#        'Road Surface', 'Lighting Conditions', 'Weather Conditions',
#        'Local Authority', 'Vehicle Number', 'Type of Vehicle',
#        'Casualty Class', 'Casualty Severity', 'Sex of Casualty',
#        'Age of Casualty'],
#       dtype='object')

# %%
df['Lighting Conditions'].value_counts().plot(kind='pie');

# %%
df['Road Surface'].value_counts().plot(kind='pie');

# %%
df['Weather Conditions'].value_counts().plot(kind='pie');

# %%
df['Casualty Severity'].value_counts().plot(kind='pie');

# %%
df['Lighting Conditions'].value_counts().plot(kind='pie');

# %%
#I want to create a map of each of their locations based on the latitude and longitude coordinates. Ideally, from df data

# %%
#KNN Nearest Neighbour model for car accident servity

# %%
import itertools
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.ticker import NullFormatter
import pandas as pd
import numpy as np
import matplotlib.ticker as ticker
from sklearn import preprocessing
# %matplotlib inline

# %%
df['Casualty Severity'].value_counts()
# Out:
# 3    1110
# 2     173
# 1      12
# Name: Casualty Severity, dtype: int64

# %%
df.hist(column='Weather Conditions', bins=50)
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x00000240F84FCDC0>]],
#       dtype=object)

# %%
df.columns
# Out:
# Index(['Grid Ref: Easting', 'Grid Ref: Northing', 'Number of Vehicles',
#        'Accident Date', 'Time (24hr)', '1st Road Class', '1st Road Class & No',
#        'Road Surface', 'Lighting Conditions', 'Weather Conditions',
#        'Local Authority', 'Vehicle Number', 'Type of Vehicle',
#        'Casualty Class', 'Casualty Severity', 'Sex of Casualty',
#        'Age of Casualty'],
#       dtype='object')

# %%
X=df[['Time (24hr)',
       'Road Surface', 'Lighting Conditions', 'Weather Conditions',
        'Vehicle Number','Sex of Casualty',
       'Age of Casualty']].values #.astype(float)
X[0:5]
# Out:
# array([[1505,    1,    1,    1,    1,    2,    3],
#        [1915,    1,    4,    1,    1,    1,   16],
#        [ 955,    1,    1,    1,    2,    2,   38],
#        [1128,    1,    1,    1,    3,    2,   46],
#        [ 746,    1,    1,    1,    1,    1,   69]], dtype=int64)

# %%
y = df['Casualty Severity'].values
y[0:5]
# Out:
# array([3, 3, 3, 3, 3], dtype=int64)

# %%
#Normalize Data

# %%
X = preprocessing.StandardScaler().fit(X).transform(X.astype(float))
X[0:5]
# Out:
# array([[ 0.19879613, -0.56772445, -0.63260709, -0.31304037, -0.82251006,
#          1.04664667, -1.71630788],
#        [ 0.98146558, -0.56772445,  1.22504866, -0.31304037, -0.82251006,
#         -0.95543226, -1.041576  ],
#        [-0.85112631, -0.56772445, -0.63260709, -0.31304037,  0.70131044,
#          1.04664667,  0.10027794],
#        [-0.52087798, -0.56772445, -0.63260709, -0.31304037,  2.22513093,
#          1.04664667,  0.51549756],
#        [-1.25009684, -0.56772445, -0.63260709, -0.31304037, -0.82251006,
#         -0.95543226,  1.70925396]])

# %%
#Train Test Split

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split( X, y, test_size=0.2, random_state=4)
print ('Train set:', X_train.shape,  y_train.shape)
print ('Test set:', X_test.shape,  y_test.shape)
# Out:
# Train set: (1036, 7) (1036,)
# Test set: (259, 7) (259,)

# %%
#Classification
#K nearest neighbor (KNN)

# %%
from sklearn.neighbors import KNeighborsClassifier

# %%
k = 4
#Train Model and Predict  
neigh = KNeighborsClassifier(n_neighbors = k).fit(X_train,y_train)
neigh
# Out:
# KNeighborsClassifier(n_neighbors=4)

# %%
#Predicting

# %%
yhat = neigh.predict(X_test)
yhat[0:5]
# Out:
# array([3, 3, 3, 3, 3], dtype=int64)

# %%
#Accuracy evaluation

# %%
from sklearn import metrics
print("Train set Accuracy: ", metrics.accuracy_score(y_train, neigh.predict(X_train)))
print("Test set Accuracy: ", metrics.accuracy_score(y_test, yhat))
# Out:
# Train set Accuracy:  0.8561776061776062
# Test set Accuracy:  0.8378378378378378

# %%
#practice

# %%
# write your code here
k = 6
neigh6 = KNeighborsClassifier(n_neighbors = k).fit(X_train,y_train)
yhat6 = neigh6.predict(X_test)
print("Train set Accuracy: ", metrics.accuracy_score(y_train, neigh6.predict(X_train)))
print("Test set Accuracy: ", metrics.accuracy_score(y_test, yhat6))
# Out:
# Train set Accuracy:  0.8658301158301158
# Test set Accuracy:  0.8455598455598455

# %%
#We can calculate the accuracy of KNN for different Ks.

# %%
Ks = 10
mean_acc = np.zeros((Ks-1))
std_acc = np.zeros((Ks-1))
ConfustionMx = [];
for n in range(1,Ks):
    
    #Train Model and Predict  
    neigh = KNeighborsClassifier(n_neighbors = n).fit(X_train,y_train)
    yhat=neigh.predict(X_test)
    mean_acc[n-1] = metrics.accuracy_score(y_test, yhat)

    
    std_acc[n-1]=np.std(yhat==y_test)/np.sqrt(yhat.shape[0])

mean_acc
# Out:
# array([0.7992278 , 0.74903475, 0.84942085, 0.83783784, 0.85328185,
#        0.84555985, 0.86486486, 0.85714286, 0.86100386])

# %%
#Plot model accuracy for Different number of Neighbors

# %%
plt.plot(range(1,Ks),mean_acc,'g')
plt.fill_between(range(1,Ks),mean_acc - 1 * std_acc,mean_acc + 1 * std_acc, alpha=0.10)
plt.legend(('Accuracy ', '+/- 3xstd'))
plt.ylabel('Accuracy ')
plt.xlabel('Number of Nabors (K)')
plt.tight_layout()
plt.show()

# %%
print( "The best accuracy was with", mean_acc.max(), "with k=", mean_acc.argmax()+1)
# Out:
# The best accuracy was with 0.8648648648648649 with k= 7

# %%
car_accident_servity = KNeighborsClassifier(n_neighbors = k).fit(X_train,y_train)
car_accident_servity
# Out:
# KNeighborsClassifier(n_neighbors=6)

# %%
yhat = car_accident_servity.predict(X_test)
yhat[0:5]
# Out:
# array([3, 3, 3, 3, 3], dtype=int64)

# %%
print("Train set Accuracy: ", metrics.accuracy_score(y_train, car_accident_servity.predict(X_train)))
print("Test set Accuracy: ", metrics.accuracy_score(y_test, yhat))
# Out:
# Train set Accuracy:  0.8658301158301158
# Test set Accuracy:  0.8455598455598455

# %%
from sklearn.metrics import classification_report

print (classification_report(y_test, yhat))
# Out:
#               precision    recall  f1-score   support
#
#            1       0.00      0.00      0.00         2
#            2       0.29      0.17      0.21        30
#            3       0.89      0.94      0.91       227
#
#     accuracy                           0.85       259
#    macro avg       0.39      0.37      0.38       259
# weighted avg       0.81      0.85      0.83       259

# %%
from sklearn.metrics import f1_score
f1_score(y_test, yhat, average='weighted')
# Out:
# 0.8261825070335708

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
md = 10
mean_acc = np.zeros((md-1))
std_acc = np.zeros((md-1))
ConfustionMx = [];
for n in range(1,md):
    
    #Train Model and Predict  
    loant = DecisionTreeClassifier(criterion="entropy", max_depth = n).fit(X_train,y_train)
    yhat=loant.predict(X_test)
    mean_acc[n-1] = metrics.accuracy_score(y_test, yhat)

    
    std_acc[n-1]=np.std(yhat==y_test)/np.sqrt(yhat.shape[0])

mean_acc
# Out:
# array([0.87644788, 0.87644788, 0.88030888, 0.87644788, 0.86872587,
#        0.85328185, 0.85328185, 0.83011583, 0.84169884])

# %%
md=10
mean_acc = np.zeros((md-1))
std_acc = np.zeros((md-1))
ConfustionMx = [];
for n in range(1,md):
     
    #Train Model and Predict  
    loant = DecisionTreeClassifier(criterion="entropy", max_depth = n).fit(X_train,y_train)
    yhat=loant.predict(X_test)
    mean_acc[n-1] = metrics.accuracy_score(y_test, yhat)

    
    std_acc[n-1]=np.std(yhat==y_test)/np.sqrt(yhat.shape[0])

mean_acc
# Out:
# array([0.87644788, 0.87644788, 0.88030888, 0.87644788, 0.86872587,
#        0.85328185, 0.85328185, 0.83397683, 0.84942085])

# %%
plt.plot(range(1,md),mean_acc,'r')
plt.fill_between(range(1,md),mean_acc - 1 * std_acc,mean_acc + 1 * std_acc, alpha=0.10)
plt.legend(('Accuracy ', '+/- 3xstd'))
plt.ylabel('Accuracy ')
plt.xlabel('Number of Max Depth')
plt.tight_layout()
plt.show()

# %%
car_accident_servity = DecisionTreeClassifier(criterion="entropy", max_depth = 4)
car_accident_servity
# Out:
# DecisionTreeClassifier(criterion='entropy', max_depth=4)

# %%
# Train the Decision tree model
car_accident_servity.fit(X_train,y_train)
# Out:
# DecisionTreeClassifier(criterion='entropy', max_depth=4)

# %%
yhat= car_accident_servity.predict(X_test)

# %%
print("Train set Accuracy: ", metrics.accuracy_score(y_train, car_accident_servity.predict(X_train)))
print("Test set Accuracy: ", metrics.accuracy_score(y_test, yhat))
# Out:
# Train set Accuracy:  0.861969111969112
# Test set Accuracy:  0.8764478764478765

# %%
print (classification_report(y_test, yhat))
# Out:
#               precision    recall  f1-score   support
#
#            1       0.00      0.00      0.00         2
#            2       0.50      0.13      0.21        30
#            3       0.89      0.98      0.93       227
#
#     accuracy                           0.88       259
#    macro avg       0.46      0.37      0.38       259
# weighted avg       0.84      0.88      0.84       259
# C:\ProgramData\Miniconda3\condabin\mni\lib\site-packages\sklearn\metrics\_classification.py:1221: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
